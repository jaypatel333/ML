# %%
import twython #Python-NLP wrapper for twitter API
import nltk

# %%
from nltk.twitter import Query, Streamer, Twitter, TweetViewer, TweetWriter, credsfromfile

# %%
oauth = credsfromfile()
client = Streamer(**oauth)
client.register(TweetViewer(limit=10))
client.sample()
# Out:
# 岡山 野村 デミカツ丼です https://t.co/Q7IAuznVrT
# 平野君祝賀イベント https://t.co/LP0HCmpg9l
# @Alano52062004 hey💕
# @Gonzalezmica24 Jajajaaaaaa se laaaa manda la wacha
# RT @psgent92264: Fran Lebowitz: 'You do not know anyone as stupid as Donald Trump'
# “Everyone says he is crazy – which maybe he is – but the…
# RT @KohlerNycole: Me tornei a pessoa que eu mais detestava, a pessoa que tá foda-se pro snap
# RT @Virmoshh17: Veni, ponete en mi lugar y fijate si aguantas
# Stephanie one nasty thing.  #60DaysIn
# RT @Esterialy: Give me a season 2 already..need Kanna in my life again https://t.co/sTZnpuknvW
# To morrendo de cólica QUE ÓDIO
# Written 10 Tweets

# %%
client = Streamer(**oauth)
client.register(TweetViewer(limit=10))
client.filter(track='refugee, germany')
# Out:
# RT @EHSANI22: There are so many golden oldies to choose from, but this from 2016 is my favorite of the night https://t.co/MqF1KGgNmA
# RT @beneltham: Australia's refugee gulags are barbaric https://t.co/FRM5BflGxb
# RT @david_manne: Here’s link to Fed Ct ruling ordering Aus Govt to bring suicidal 10yo #refugee boy to Aust - despite Govt objections https…
# RT @ian_costaj: Our new flag since the parrot dem go germany https://t.co/eW5iAJqg6c
# @ShellenbergerMD Screwed up Germany, now trying for South Korea
# RT @ImranKhanPTI: KP's original pledge was for 348000 ha of forest restoration (achieved in 2017); now ADDITIONAL forest restoration of 252…
# RT @spectatorindex: Projected GDP PPP in 2050. ($ trillion)
#
# China: 58.5
# India: 44.1
# US: 34.1
# Indonesia: 10.5
# Brazil: 7.5
# Russia: 7.1
# Mexic…
# RT @KDorr45: Senate Foreign Relations Dem @ChrisCoons has it right - “The vacancy in Germany has gone on just far too long.” The Senate sho…
# ...

# %%
client = Query(**oauth)
tweets = client.search_tweets(keywords='Trump', limit=1000)
tweet = next(tweets)
from pprint import pprint
pprint(tweet, depth=999)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Mar 23 02:23:54 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 14247236,
#                                  'id_str': '14247236',
#                                  'indices': [3, 10],
#                                  'name': 'Scott Dworkin',
#                                  'screen_name': 'funder'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 977008005043642370,
#  'id_str': '977008005043642370',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 603,
#  'retweeted': False,
# ...

# %%
tweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
print(text)
data = ""
# Out:
# RT @Sarah_Boxer: Today Trump lost a top lawyer &amp; a top general. The roles are being filled with people he watches on @FoxNews.

# %%
for tweet in tweets:
    data += tweet['text']

# %%
len(data)
# Out:
# 133445

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# %%
import io
from nltk.tokenize import word_tokenize
words = data.split()

# %%
len(words)
# Out:
# 19937

# %%
type(words)
# Out:
# list

# %%
print(words)
# Out:
# ['RT', '@AutisticFlame:', 'New', 'tariffs', 'placed', 'on', 'China', 'https://t.co/gQDcIayqH2', 'https://t.co/Llcas6LhJFRT', '@FiveRights:', 'Another', 'indication', 'that', 'Mark', 'Anthony', 'Conditt', 'is', 'a', 'leftist:', 'Facebook', 'scrubbed', 'his', 'account', 'clean.', 'Do', 'you', 'think', 'Facebook', 'would…RT', '@RealMuckmaker:', 'When', 'will', 'the', 'damage', 'Trump', 'is', 'doing', 'be', 'enough', 'for', 'Republicans', 'to', 'stand', 'up', 'to', 'him?', 'https://t.co/5xkA1jkf9DFox', 'News', 'is', 'ignoring', 'Trump’s', 'alleged', 'affair', 'with', 'Stormy', 'Daniels', 'https://t.co/ShIyuGgpBgRT', '@CollinRugg:', 'Joe', 'Biden:', '“I', 'would', 'kick', 'Trump’s', 'ass”', 'Dems:', '“LOL!', 'Good', 'job', 'Biden”', 'Trump', 'defending', 'himself:', '“No', 'you', 'wouldn’t.', 'You', 'would', 'go…RT', '@AshleyRParker:', 'Just', 'your', 'periodic', 'and', 'helpful', 'reminder', 'that', 'just', 'because', 'the', 'White', 'House', 'denies', 'a', 'story', 'doesn’t', 'mean', 'i
# ...

# %%
import re

# %%
all1 = r'^[a-zA-Z0-9!@#\$%\^\&*\)\(+=._-]+$)'
slash_all = r'\s*(?:[\w_]*[/\\](?:[\w_]*[/\\])*[\w_]*)'
[^A-Za-z0-9]+

# %%
strt = re.sub(slash_all,"",words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-a896146a2181> in <module>()
# ----> 1 strt = re.sub(slash_all,"",words)
#
# ~\Anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
#     190     a replacement string to be used."""
# --> 191     return _compile(pattern, flags).sub(repl, string, count)
#     192
#     193 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
words1=[]
counter = 0
for word in words:
    strt = re.sub('\W+', '', word)
    words1.append(strt)
    counter += 1

# %%
len(words1)
# Out:
# 19937

# %%
print(counter)
# Out:
# 19937

# %%
from nltk.corpus import stopwords
s=set(stopwords.words('english'))

txt="a long string of text about him and her"
(filter(lambda words: not words in s,txt.split())
# Out:
# ['long', 'string', 'text']

# %%
len(words)
# Out:
# 17914

# %%
from nltk.book import *
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
type(text4)
# Out:
# nltk.text.Text

# %%
results  = []
for sentence in words:
    sentence_results = []
    for s in sentence:
        sentence_results.append(nltk.word_tokenize(sentence))
    results.append(sentence_results)

# %% [raw]
# print(results[0])

# %%
import os
from os import path
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS

# %%
text=open('Twitter.txt',"r")
wordcloud = WordCloud().generate(text)

# %%
wordcloud = WordCloud(font_path='ARegular.ttf',background_color='white',mode='RGB',width=4000,height=2000).generate(text)
plt.title("Tweets related to Donald Trump")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("twitter.png")
